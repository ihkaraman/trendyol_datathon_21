# %% [markdown]
# https://www.kaggle.com/burhanbilenn/duygu-analizi-icin-urun-yorumlari?select=magaza_yorumlari_duygu_analizi.csv

# %%
import pandas as pd
import re
import zeyrek
from collections import Counter
import nltk

# %%
data_path = r'C:\Users\IsmailKaraman\workspace\data\trendyol\\'

# %%
data_reviews = pd.read_csv(data_path+"reviews.csv")
data_qa = pd.read_csv(data_path+"qa.csv")

# %%
data_reviews.shape
# Out:
# (6176841, 5)

# %%
data_qa.shape
# Out:
# (1450961, 5)

# %%
data_reviews.head()
# Out:
#    product_content_id  rate  \
# 0            35244093     5
# 1            97842293     5
# 2            86701595     5
# 3           107237246     3
# 4            45019480     5
#
#                                              comment  review_like_count  \
# 0  75c göğüse S beden aldım spor için daha da sar...                NaN
# 1                     fiyatı yüksek ama çok memnunum                NaN
# 2  yorumlara ve beden tablosuna bakarak 1 beden b...                1.0
# 3                 çok kısa iade ettim. sıradan geldi                NaN
# 4                            Renkler daha canlı. Hoş                NaN
#
#    supplier_id
# 0          968
# 1          367
# 2       191874
# 3          968
# 4          968

# %%
all_reviews = ' '.join(data_reviews.comment)

# %%
all_reviews[0:100]
# Out:
# '75c göğüse S beden aldım spor için daha da sarmasını isterdim fakat xsde küçük olacak gibi fiyatı yü'

# %%
all_reviews = all_reviews.split(' ')

# %%
len(all_reviews)
# Out:
# 74717663

# %%
review_counts = Counter(all_reviews)

# %%
review_counts
# Out:
# Counter({'': 1,
#          'arasıydı,': 1,
#          'xarike': 1,
#          'Pamukluolduğundan': 1,
#          'yırtmacıbacağa': 1,
#          'değiliginin': 1,
#          'kalıpalınmasını': 1,
#          'bəyəndim.💗Tarz': 1,
#          'sıcacık.Herkesalsin': 1,
#          'bedeninizialabilirsiniz..tavsiye': 1,
#          'kaldı.tam': 1,
#          'dusunuyorum.inanilmaz': 1,
#          'gürür': 1,
#          '5/10': 1,
#          'sünüyorbedenınızden': 1,
#          'u2ertesi': 1,
#          'gelmedi..Sorup': 1,
#          'güzelke,': 1,
#          'oturdu167': 1,
#          'oluştu.Yinede': 1,
#          'yumuşaksayılır': 1,
#          'alakasızzzz': 1,
#          'bikinisiolabilir.': 1,
#          'alışık': 1,
#          'hattahic': 1,
#          'ustumküçük': 1,
#          'tıftıklendı': 1,
#          'yamukgözüküyorsunuz': 1,
#          '47_48': 1,
#          'değilmüşteriyi': 1,
#          'kumaş.boy': 1,
#          'bayasicak': 1,
#          'olmuyor.Daha': 1,
#          'olsun10': 1,
#          'edebilirsiniz.Benimbasenlerim': 1,
#          'hızlıverseker': 1,
#          'lpgemle': 1,
#          '🤪😎': 1,
#          'ayrılıo': 1,
#          'kıyafetinebenziyor': 1,
#          'için3x': 1,
#          'edemeden☹️': 1,
#          'bozulacakgibi.Siyahı': 1,
#          '162/65,': 1,
#          'suphesiz': 1,
#          'renkti!': 1,
#          'paketlemeyapıyor': 1,
#          'aynı1,68': 1,
#          'iade🤐': 1,
#          'alabilirisiniz&lt;3': 1,
#          'örmeler': 1,
#          'sarkıyo🤦\u200d♀️🥴': 1,
#          'değisir': 1,
#          'bile.1.67': 1,
#          'bileğinizin': 1,
#          'hediyekurtarıcım': 1,
#          'alabilirsniz.73': 1,
#          'gelmedi.naylon': 1,
#          'elbisecik': 1,
#          'alınabilir,çünkü': 1,
#          'ileetiketteki': 1,
#          'bolluktadurdu.Açıkçası': 1,
#          'yapışıo.': 1,
#          'Mükemmel,renk': 1,
#          'KAHVERENGİNE': 1,
#          'yorunlar': 1,
#          'çıkarttiginizdakollar,': 1,
#          'içiniziaçıyor.Görseldekiyle': 1,
#          'etek.arkadaşımın': 1,
#          'dilinizle': 1,
#          'oturuncayukarıya': 1,
#          'çalıştımdüz': 1,
#          'beğendim.umarım': 1,
#          'gibişeylerde': 1,
#          'kalıngözükse': 1,
#          'NİŞANDA': 1,
#          'ama.Cepleri': 1,
#          'deneyinceçok': 1,
#          'parlaklığıkalitesi': 1,
#          'medium.Mankendeki': 1,
#          'havasınauygun.': 1,
#          'YILİNİZİ': 1,
#          'sorgusuzca': 1,
#          'jogginglerine': 1,
#          'biseyhic': 1,
#          'iadeetmezdim.': 1,
#          'bolkalma': 1,
#          'giyiyor..Bedeninizi': 1,
#          'giriyorsunuzgiyebilmek': 1,
#          'kucugde': 1,
#          'verinyorumlari': 1,
#          'xLgiymeme': 1,
#          'neeee': 1,
#          'bozulacak😏': 1,
#          'yırtıklarıdiz': 1,
#          'değil.Fiyat/performans': 1,
#          'mükkkk.': 1,
#          'müsaitalır': 1,
#          '(1.68-50': 1,
#          'rağmensütyensiz': 1,
#          'alın.Anca': 1,
#          'dedüşünüyorum': 1,
#          'taklak': 1,
#          'mükemmell👍': 1,
#          '.amakumasi': 1,
#          'buzda': 1,
#          'cotton,': 1,
#          'Eriket': 1,
#          'Bulamazsam': 1,
#          'liona': 1,
#          'durduuzunluguda': 1,
#          'incealtına': 1,
#          'esnekliligi': 1,
#          'olundu\U0001f90c🏼': 1,
#          'ürünümböyle': 1,
#          'böylevücudunu': 1,
#          'aararsa': 1,
#          'ciddidikiş': 1,
#          'cevaplıyor,': 1,
#          'defoluolduğu': 1,
#          '160boy.normalde': 1,
#          'gözealın.': 1,
#          'haklıymış.Esim': 1,
#          'genişorantısızlık': 1,
#          'batmasındanbirazcık': 1,
#          'diyebiliriz.kalın': 1,
#          'durmadı.40beden': 1,
#          'kullandım,aşırı': 1,
#          'ürünün(m/l': 1,
#          'بلون': 1,
#          'kisaliyo': 1,
#          'aranızgörünüyor': 1,
#          'dagıtmatekrar': 1,
#          'inanılmazterletiyor.': 1,
#          'ürünkışın': 1,
#          'ifil-ifil.': 1,
#          'memeölçüsüne': 1,
#          'yok.paketin': 1,
#          'sıradagorunmesi': 1,
#          'oldu😍güncelleme': 1,
#          'baharlıkfiyatına': 1,
#          'düşünülmüş.Tok': 1,
#          '(1.98': 1,
#          'PAKETLEMEOLMADAN': 1,
#          'penti’den': 1,
#          'yakabilir63': 1,
#          'istemiyomus': 1,
#          'güzelsiin😍': 1,
#          'vebitlendi': 1,
#          'yuzdentam': 1,
#          'jeanininceliğinden': 1,
#          '👆🏻': 1,
#          'начали': 1,
#          'Resimdekiylegelen': 1,
#          'görünüyor👎': 1,
#          'cilde': 1,
#          'giyecekmis)': 1,
#          'bacaktansıktığı': 1,
#          'GİYİNİR': 1,
#          'bedenkullaniyorum.': 1,
#          '(160-44)': 1,
#          'hallederin': 1,
#          'yanlışolmuş,': 1,
#          'yansıtmakyanlış': 1,
#          'eylenceli.': 1,
#          'yumuşacık.Lufian': 1,
#          'lazımyerlerde': 1,
#          'aşırırrrıgüzel': 1,
#          'olmasınane': 1,
#          'ulaştırezalet': 1,
#          '34daha': 1,
#          'harika🙂tam': 1,
#          'tarafındatam': 1,
#          'beğendi.Renkler': 1,
#          'gibi.Kenarlardan': 1,
#          'abartılcakbişeyi': 1,
#          'kısaltmalık': 1,
#          'iyi❤🥰': 1,
#          'ederim.1.62': 1,
#          'kollu!': 1,
#          'cekiyorum,yirtmaci': 1,
#          'boyunbağınınaltı': 1,
#          'bedenisarisi': 1,
#          'değcekbi': 1,
#          'kalmıyorüstelik': 1,
#          'Ayrıcamankendeki': 1,
#          'daralttirilir': 1,
#          'oversizrdurması': 1,
#          'Bayıldıkkkkkkkk': 1,
#          '2-3cmkestireceğim': 1,
#          'kovaliyordum.': 1,
#          'şortustune': 1,
#          'gömlek,ince.güvenle': 1,
#          'vazgeçmemisi': 1,
#          'var,elektrikleniyor,kesinlikle': 1,
#          'bilgilerdebelirtildiği': 1,
#          'giyiyorumpenyesi': 1,
#          'Icini': 1,
#          '(satışta': 1,
#          'begenir😄': 1,
#          'küçükl/xl': 1,
#          'indirimlialdım,bir': 1,
#          'buzusmus...cokbegenmedim.zayiflarda': 1,
#          '25değilde': 1,
#          'kestirwbilirim.': 1,
#          'haletimrengide': 1,
#          'tarzkiiii': 1,
#          'vetrendyolmillada': 1,
#          'benmisuçluyum': 1,
#          'kisa.super': 1,
#          'desemtrendyoldan': 1,
#          'aldırın🤓': 1,
#          'sepetimdekileri': 1,
#          'bölebir': 1,
#          'şeffafposette': 1,
#          'yerde"r"': 1,
#          'geldi.Kapalılar': 1,
#          'klasikdolapta': 1,
#          '🥺😩': 1,
#          'Şapkalısweatlerimle': 1,
#          '.bnmkizim': 1,
#          'KAPANMAZMIŞOYÜZDEN': 1,
#          'bolduterside': 1,
#          'suyunaltında': 1,
#          'yksı': 1,
#          'Yorumlardanokuyarak': 1,
#          'dandikdaha': 1,
#          'harıç': 1,
#          'güldü🥰': 1,
#          'tercihlerimi': 1,
#          'yakıştı❤️': 1,
#          'oluyosebebini': 1,
#          'edit': 1,
#          'ozensiz...': 1,
#          'yanibollaşıyor': 1,
#          'büyükgörselde': 1,
#          'jsjwkekwke': 1,
#          'bitimkısmında': 1,
#          'kalitedegüzel': 1,
#          'boy:1.68': 1,
#          'aldim.15': 1,
#          'kıvamında.Bej': 1,
#          'şortlarınelbiselerin': 1,
#          'rengidesevdim': 1,
#          'küpurleri': 1,
#          'Fistosu': 1,
#          'Guzeeeelll': 1,
#          'yüksektopukluyla': 1,
#          'sığmadığıiçin.': 1,
#          'Guzel✌🏻': 1,
#          'BAYILDIM,BAYILDIM,BAYILDIM': 1,
#          'amaalın': 1,
#          'minare': 1,
#          'yim..38': 1,
#          'KALKMAYIN': 1,
#          'elbiseyleorantisiz.': 1,
#          'bideboyun': 1,
#          'falanim61': 1,
#          'Gibi..👏👏..': 1,
#          'olarakepeyce': 1,
#          'koymuşum': 1,
#          'kaldı\U0001f972': 1,
#          'yılardır': 1,
#          'ürün😊😇': 1,
#          'tatlı.gayet': 1,
#          'kurumasınasıl': 1,
#          'Sayınöncelikle': 1,
#          'Kızlaaaaae': 1,
#          'değil.Tam': 1,
#          '1.71kilo': 1,
#          'kaliteliydi.Baskısı': 1,
#          'muhteşem.göğüs': 1,
#          'parçalar.kumaşları': 1,
#          'kızimaküçük': 1,
#          'kumaşyorumlarda': 1,
#          'yıldızfarkı': 1,
#          'bulamiyodum...Acikcasi': 1,
#          'hususları': 1,
#          'bekleriz♥️': 1,
#          'iyiki🙏1.70': 1,
#          'terzide.Ürüne': 1,
#          'mi?cok': 1,
#          'bedençooook': 1,
#          'yaziyordu.Annemin': 1,
#          'satışçılık,': 1,
#          '(160/43)': 1,
#          'puanağ': 1,
#          'hemenhesabıma': 1,
#          'vasat.rengide': 1,
#          'tatyçok': 1,
#          'Resimyaparken': 1,
#          'kızımbeğendi': 1,
#          'marka.Sirt': 1,
#          'gümü': 1,
#          'öneririmhatta': 1,
#          'efil,mutlaka': 1,
#          'yumusakbende': 1,
#          'BEYNİ': 1,
#          'harika.24': 1,
#          'shortie': 1,
#          'kesinürün': 1,
#          'Jestleri': 1,
#          'paçalarınıuzun': 1,
#          'yumak': 1,
#          'fiyataiade': 1,
#          '167-60kg’yim': 1,
#          'olmaz🤩': 1,
#          'terstende': 1,
#          'bende,iyi': 1,
#          'özenli.Teşekkürler⭐️': 1,
#          'yazmıyoretiketi': 1,
#          'oturuşu,bedeni': 1,
#          'siparişimi.hemen': 1,
#          'bayılacaksınız:)bir': 1,
#          'oldu.(Umarım': 1,
#          'veüzerindeyken': 1,
#          '200tlüzeri': 1,
#          'oldu,alırken': 1,
#          'gibiyıkanmadı': 1,
#          'pamukluymus.': 1,
#          'sanarakbaşka': 1,
#          'limonirenk.': 1,
#          'kığkırmızı': 1,
#          'üzerimdeM': 1,
#          'yahu?Dalga': 1,
#          'kaymışvaziyette.': 1,
#          'gibi...Rengi,dokusu': 1,
#          'yağınız': 1,
#          'zamanlardagiyilecekse': 1,
#          '1.68-62': 1,
#          'geçtimgiymeden': 1,
#          'icinegirebilir': 1,
#          'kalıp.gercekten': 1,
#          'yerdebitseymiş': 1,
#          'kıvrımınızbelirginse': 1,
#          'üründekoldaki': 1,
#          'kiyaslayacaktim.': 1,
#          'jeansim.': 1,
#          'muhakKak': 1,
#          'memnunuyetimi': 1,
#          'herşeyibeğenmem.': 1,
#          'kısımlardakivrilmalar': 1,
#          'fiyatperformansi': 1,
#          'iyi,özenli': 1,
#          'hayır.Kaliteli': 1,
#          'dersindewc': 1,
#          'Aşşagıda': 1,
#          'NBBnin': 1,
#          'akıyorderler': 1,
#          '👍🏼😇🥰': 1,
#          'oyüzden3puan': 1,
#          'küçük.Kalıbın': 1,
#          'zatenyenidogan': 1,
#          'ütüyeüşenmezseniz': 1,
#          'performansindan': 1,
#          'nolacal': 1,
#          'duruşuşahane.Normalde': 1,
#          'kalmamıştıbüyük': 1,
#          'yapmıyorsunuz...': 1,
#          'gore)': 1,
#          'giydiriyorum,': 1,
#          'durdugündelik': 1,
#          'Rezalet..on': 1,
#          'kısmındakoca': 1,
#          'durmazmiş': 1,
#          'kslsç': 1,
#          'değil..etiketi': 1,
#          'koyarakyollamışlar': 1,
#          'ürüngeldi.Birisi': 1,
#          'hamilelerdegiyebilir': 1,
#          'normalolmasına': 1,
#          'etkisioluşmadı.': 1,
#          '‼️‼️ÜSTÜNE': 1,
#          '🙈🙉🙊hiç': 1,
#          'özellikleharika': 1,
#          'boyadıresmen': 1,
#          'cıvıltılı.': 1,
#          'Guxel': 1,
#          'Yirtiq': 1,
#          'gelmesikaçınılmaz.': 1,
#          'yinesıktı.': 1,
#          '.Elbisenin': 1,
#          'müşteriyleilgi': 1,
#          'kırışmiyor': 1,
#          'Dargiyinmediğim': 1,
#          'ipleriistediğim': 1,
#          'ikenindirimden': 1,
#          'teşekkürler,daha': 1,
#          'liğrasız': 1,
#          'göğüslüve': 1,
#          'Kollarılastikli': 1,
#          'kapatmamak': 1,
#          'ortadadirek': 1,
#          'değil.askilariayarlanabilir': 1,
#          'hattailk': 1,
#          'normakde': 1,
#          'var.potluk': 1,
#          'Desenimden': 1,
#          'Çeşitliliğini': 1,
#          'beyendi,iyi': 1,
#          'Eğlendim': 1,
#          'sekilli': 1,
#          'dışındasevdiğim': 1,
#          'onbiryaşındaki': 1,
#          'tokyo': 1,
#          'normaldeS': 1,
#          'bedeniji': 1,
#          'oldu...Mde': 1,
#          'insanıiçinde.': 1,
#          'olması:(((ama': 1,
#          'Normaldepembe': 1,
#          'oldu.Şeker': 1,
#          'içinegiyerim.': 1,
#          'Yünlüler': 1,
#          'dahakalindi': 1,
#          'neredeyseilk.': 1,
#          'gondermisler,utanmadan.......': 1,
#          'buldmkeyifli': 1,
#          'edemiycegim': 1,
#          'üzerinemüthiş': 1,
#          'Kuzenimi': 1,
#          'alsıınnnnnnn': 1,
#          'erkenkaybediyor.': 1,
#          'geldi😭🤦🏻\u200d♀️': 1,
#          'insanlarıgerçekten': 1,
#          'sahipdeğildi': 1,
#          'haftadafarkı': 1,
#          'sıkıtopluyor': 1,
#          'olarak.Ancak': 1,
#          'beğendi.Anneler': 1,
#          'kışınkullanışlı': 1,
#          'altımaydı': 1,
#          'hemM': 1,
#          'Basendenkasar': 1,
#          'yumuşak.ürün': 1,
#          'kalıpları2': 1,
#          'tarafındangidilebileceğine': 1,
#          'takımaldığım': 1,
#          'baglayamıyorsun': 1,
#          'haldebenden': 1,
#          'kötü.Giymemle': 1,
#          'şeygeldi.Ancaq': 1,
#          'verilən': 1,
#          'Ntuğçecaner': 1,
#          'kokusugittin': 1,
#          'edicem.Fotoğrafta': 1,
#          'sağlanmaması': 1,
#          'fakatsırtındaki': 1,
#          '67-68': 1,
#          'şeyimçok': 1,
#          'OLUŞTU.BİRDE': 1,
#          'amagirerken': 1,
#          'BULUNDURARAK': 1,
#          'gunükurtariyor': 1,
#          'takipteyimgerçekten': 1,
#          'sbaahlik': 1,
#          'farkınavarmadım': 1,
#          '24_36aldim': 1,
#          'Bedenioldu,': 1,
#          'gönderin...Sahte': 1,
#          'etmemiştim👌': 1,
#          'karıştırıyoruz': 1,
#          'ayarlıyabiliyorsunuziplerini': 1,
#          'beklemesin': 1,
#          'gri.eski': 1,
#          'üstündegeniş': 1,
#          'Kalıbıenteresan.': 1,
#          'fakatstoklarını': 1,
#          'ceketidaha': 1,
#          'yumuşacıkrahatlıkla': 1,
#          'Üzüldüm.😒': 1,
#          'dokunduğunuzanda': 1,
#          'carmen.': 1,
#          'öncefarklı': 1,
#          'kopukgeldi.': 1,
#          'buyukalin.kalitesi': 1,
#          'tıkmış.': 1,
#          'altlları': 1,
#          'düşündüğümdenkısa': 1,
#          'asiriuzun.jeanlerle': 1,
#          'alınmalı.tesekkurler': 1,
#          '❤bayıldım': 1,
#          'üzerime😍': 1,
#          'tarzolabilir.': 1,
#          'geçmedi...o': 1,
#          'güzel☺️🇹🇷': 1,
#          '6295.': 1,
#          'DEKOLTESİZ,': 1,
#          '(boy167': 1,
#          'sevdim😈': 1,
#          'yollasaydiniz..': 1,
#          'ragmenkardeşim': 1,
#          'Terzideistediğim': 1,
#          'verdimremdekiyle': 1,
#          'gonderdikdike': 1,
#          'hoppidik': 1,
#          'berbat,kalıbı': 1,
#          'Icindekipedlerde': 1,
#          'mayolargozukur.': 1,
#          'alabilir,biz': 1,
#          'ürünükargolamışlar': 1,
#          'bulunankırmızı': 1,
#          'Sıcaklık': 1,
#          'olmalıydım': 1,
#          'yapıyorsunuz?İşinizi': 1,
#          'tamustunde.': 1,
#          'geldi.Gayet': 1,
#          'Bistandardı': 1,
#          'kışlık🍀': 1,
#          'HARİKA...50': 1,
#          'ürününüzebakmıyor': 1,
#          'aralardasiyahliklar': 1,
#          'bileyapabilirsiniz': 1,
#          'oldum🥳🥳': 1,
#          'kiloyum.Markanın': 1,
#          'çokyaktığını': 1,
#          'sorunu:': 1,
#          'baskıaynısı': 1,
#          'tişötlerde': 1,
#          'sadece(etek': 1,
#          'bayıldııımmm!': 1,
#          'etmekteistemiyorum': 1,
#          'zarif,yumuşacık': 1,
#          '173-175': 1,
#          'Gayetmemnun': 1,
#          'tesekkurler.Hediye': 1,
#          'almamisimolmazdi..': 1,
#          'alırmışim': 1,
#          'cokbegendim.Boyu': 1,
#          'haftayadiğerleri': 1,
#          'istiyrsaniirm': 1,
#          '.bileklerimden': 1,
#          'gelenelbiselerin': 1,
#          'piyasadakidiğer': 1,
#          'oluyorlarprofesyonel': 1,
#          'daralttırdıktansonra': 1,
#          'giydiktenyarim': 1,
#          'işte.fazla': 1,
#          'kalip;şik': 1,
#          'kilo26/32': 1,
#          'cokmevsim': 1,
#          'lastiko': 1,
#          'endişeliyim.': 1,
#          'bncekalibi': 1,
#          "ebebek'in": 1,
#          'kesmeyeniletisimi': 1,
#          'Müüthiiiş': 1,
#          'Boy:181cm': 1,
#          'geldi.Satıcıya': 1,
#          'alınabilir.onun': 1,
#          'ywsil': 1,
#          'kanatlansın': 1,
#          'yarısınabile': 1,
#          'alınabilri,rengi': 1,
#          'toparlasin,': 1,
#          'kaymazolması': 1,
#          'lekelrivardı': 1,
#          'Baksın': 1,
#          'bittanrdaha': 1,
#          'oldu,bi': 1,
#          'DIMMMMM!!!': 1,
#          'gösteriyor.fotoğraftaki': 1,
#          'gibikargolaması': 1,
#          'durduhayatimda': 1,
#          'sapanarkadaşlar': 1,
#          'derim.Siyah': 1,
#          'vetulumları': 1,
#          'kullandıkçabaya': 1,
#          'kilodur.9-10yas': 1,
#          'yirtiklar,cep': 1,
#          'olmazsınız😍Harika': 1,
#          'BİRİYDİ': 1,
#          'bileüzerine': 1,
#          'tişört.severek': 1,
#          'sevinerım': 1,
#          'kaldım.Kumasi': 1,
#          'halegetirmiş': 1,
#          'kesnlkledeğil': 1,
#          'normaldurdu,': 1,
#          'desenidikişleri': 1,
#          'tirilmi': 1,
#          'üsts': 1,
#          'iyi,paketlemesi': 1,
#          'bloggerlara': 1,
#          'göregelen': 1,
#          'deyil.renkleri': 1,
#          'Silikonlusütyenlerden': 1,
#          'alabilirsiniz.Sarkana': 1,
#          'fotoğrfata': 1,
#          'modelile.': 1,
#          'kaldımtutmazsam': 1,
#          'kalın.40': 1,
#          'kaldımdünya': 1,
#          'rahat...Renkleride': 1,
#          'kargogeliyor': 1,
#          'asisttana': 1,
#          'kaliteli,indirimden': 1,
#          'bekliyordunuz...': 1,
#          'sevenleretavsyem': 1,
#          'katlamalıkgüzel': 1,
#          'çoooooooooookmemnun': 1,
#          'değilbileklerimde': 1,
#          'ınkalıbı': 1,
#          'kısmıdabiraz': 1,
#          'Gerivermiyorum': 1,
#          'yazlık🌞🌞': 1,
#          'ARAYANLARR.': 1,
#          'ketengörüyorum.': 1,
#          'kalıbımanken': 1,
#          'garip.Kumaşını': 1,
#          'gosrseldeki': 1,
#          'defovarmış': 1,
#          '(1.65boyundayım).': 1,
#          'kuryelerle': 1,
#          'Güzelmiş,beklemiyodum': 1,
#          'tatlı🌹': 1,
#          'deodoranttemasında': 1,
#          'indikesinlikle': 1,
#          'yüzdenarkafsaşımada': 1,
#          'göğsütoparlayan': 1,
#          'geldiğinde,üzülerek': 1,
#          'olurlardan.': 1,
#          'kapsızdıbu': 1,
#          'pedideiçinde': 1,
#          'takım👍1.60': 1,
#          'alabilirsiniz.Kolyelerle': 1,
#          'bahçekapısının': 1,
#          'vehareketimi': 1,
#          'nasılboydan': 1,
#          'görünüşteki': 1,
#          'kuvırdığımdan': 1,
#          'geldi..begendim': 1,
#          'muhtrşem': 1,
#          'tirilsuan': 1,
#          'elbise.basenleriniz': 1,
#          'nlı': 1,
#          'Merikbu': 1,
#          'uzatman': 1,
#          'gibiaçamıyorum': 1,
#          'ettisonuna': 1,
#          'fiyatiyi,': 1,
#          'Şa-ha-ne.': 1,
#          'gercekten,elbise': 1,
#          'teşekkürlerballı': 1,
#          'hijyenianlam': 1,
#          'Fotogradtakinin': 1,
#          'bunlarlaçalışması': 1,
#          'istemiştimtam': 1,
#          'kullanmayakara': 1,
#          'dizortasında,': 1,
#          'popurcuklanmasa': 1,
#          'ben2hafta': 1,
#          'yokamoz': 1,
#          'duruyodur.': 1,
#          'gedli,': 1,
#          'jean✨': 1,
#          'si.': 1,
#          'kabuledip': 1,
#          'amabundaki': 1,
#          'gitmrdi.': 1,
#          'basarılar.': 1,
#          'idealkap': 1,
#          'bedenimialicam': 1,
#          'pamukluastari': 1,
#          'indirimdenaldıpım': 1,
#          'incemalzemeside': 1,
#          'kumaşıiyiydi': 1,
#          'kargocü': 1,
#          'taröınımsı': 1,
#          'SEVGİLİ': 1,
#          'sefilgibi': 1,
#          'boy❤️': 1,
#          'kısıtlıyor': 1,
#          'ulaştı..tsk.trendyol': 1,
#          'genişgörseldeki': 1,
#          'beğendim.üste': 1,
#          'patikli.ama': 1,
#          'mağazalarıolan': 1,
#          'modellerinirenklerinide': 1,
#          'SANKŞ': 1,
#          'halegetiriyor.': 1,
#          'begenebilecegimi': 1,
#          '...beklentımin': 1,
#          'yapisiyo.': 1,
#          'İnanılmazbeğendi.': 1,
#          'kasmadıama': 1,
#          'verdi.basta': 1,
#          'bayıldım.Iğıl': 1,
#          'gözəl,kefiyyətli.': 1,
#          'fiyatı350': 1,
#          'sürme': 1,
#          'giyicem🥰': 1,
#          'degil.etekte': 1,
#          'zorundakalmam': 1,
#          'bakamıyorum.çünkü': 1,
#          'bunaltıcıhavalarda': 1,
#          'terletmezde,tarzı': 1,
#          'Malgeldi': 1,
#          'trendyol.:)': 1,
#          'kalitesiz..sinirimden': 1,
#          '48kiloyum34tam': 1,
#          'ürün...hem': 1,
#          'teşekkürler.kötü': 1,
#          'bebekçamaşırı': 1,
#          'mütişşşşş': 1,
#          'bildirmediler': 1,
#          'yazlarısıcaktan': 1,
#          'ettiripsıkmayacak': 1,
#          'sökülüyordikişleri.': 1,
#          'alın,normal': 1,
#          'boy168-54kg.': 1,
#          'urunmuw': 1,
#          'azıdnanetekli': 1,
#          'tanenormal': 1,
#          'uzun,ayakkabının': 1,
#          'veyırtılıcak': 1,
#          'bedenalınabilir,boy': 1,
#          'tam.çocuğunuzun': 1,
#          'canimlarrr': 1,
#          'sirtlerden.': 1,
#          'böylemodeller': 1,
#          "40'ınıngelmesini": 1,
#          'kısmni': 1,
#          'hemfikirolucağımızı': 1,
#          'pantalon,paça': 1,
#          'alabilirsiniz,zarif': 1,
#          '😊🙏🏽🙏🏽': 1,
#          'yazmadigi': 1,
#          '.Ancakçok': 1,
#          'görünmemin': 1,
#          'kullanmıyordum.Bunun': 1,
#          'sutyenlerlegiymeyi': 1,
#          'bacaklarmükemmel': 1,
#          'herkz': 1,
#          'türlüyakar': 1,
#          'ayağınatakılmasın': 1,
#          '💣👍': 1,
#          'atletsizkullanilmaz,cepsiz': 1,
#          'isterimbenim': 1,
#          'özel..ben': 1,
#          'fermuarlıalacaklar': 1,
#          'BEnim': 1,
#          'beşbuçuk': 1,
#          'kendisibirazda': 1,
#          'vucudusardigi': 1,
#          'yakındak': 1,
#          '😊😉🥰': 1,
#          'oranınagöre': 1,
#          'emeklerinenezaketlerine': 1,
#          'özellikle.hicbirseyee': 1,
#          'kullandığımızdan': 1,
#          'sıkıntılıolduğu': 1,
#          'normalmi?Kat': 1,
#          'çokkırışmaya': 1,
#          'yanılttın.': 1,
#          'aradapaçası': 1,
#          'egilmenizde': 1,
#          'ufakmi': 1,
#          'yok.cocuk': 1,
#          '85c-90': 1,
#          'ebebeek': 1,
#          'güncelliycem…': 1,
#          '163/53um': 1,
#          'oğlumsahiplendi.': 1,
#          'düşündükçehala': 1,
#          'şık,hiç': 1,
#          'varsabilirler': 1,
#          'brürün': 1,
#          'paça😁millanınkileri': 1,
#          'diyeendişelenmistim,': 1,
#          'gelidginde': 1,
#          'oversizesevdiğimden.': 1,
#          'Doğumgününde': 1,
#          'kendimok': 1,
#          'sahiptianında': 1,
#          'göğüsbüyük': 1,
#          'guzle.alin.iyi': 1,
#          'ekrugeldi.': 1,
#          'oturunca,': 1,
#          'çokgecikmedi.': 1,
#          'hediye.Çok': 1,
#          'yamukfarketaeydim': 1,
#          'düzelir.düzelir': 1,
#          'siyahınıaldim': 1,
#          'harikaaa3': 1,
#          'ürüngondəriblər': 1,
#          'istiyosabiz': 1,
#          'üstenaltta': 1,
#          'edilmeli.Yüksek': 1,
#          'Tüylenmese': 1,
#          'upper': 1,
#          'hizliydi.tesekkirler': 1,
#          'cıvıtıyorlar': 1,
#          'güel:):):)*-**-**-*-*-*-*-**-*-**-*-*-*-*-*-*?_?': 1,
#          'girişimciolarak': 1,
#          'Hatikaaaaaaa': 1,
#          'iyi.Under': 1,
#          'giyildiğindesırıtmayacak': 1,
#          'başlattımama': 1,
#          'paantolun': 1,
#          'girişler': 1,
#          'çağrıştırıyorbayıldım.': 1,
#          'olur.Dolgusunu': 1,
#          'kalmişdım': 1,
#          'yinekopacak': 1,
#          'şifonama': 1,
#          'zıp': 1,
#          'olacak.Kışın': 1,
#          '!!!😠': 1,
#          'anlamdim': 1,
#          'üsttekalması': 1,
#          'ferqlidi.tam': 1,
#          'pjamalarımbundan': 1,
#          'pardesüyü': 1,
#          'kiloverincede': 1,
#          'Olmamış': 1,
#          'göndermişler.merak': 1,
#          '1,70neredeyse': 1,
#          'gönderıldı': 1,
#          'bayiliriz': 1,
#          'fotograftançok': 1,
#          'birazkısalttırabilirsiniz.': 1,
#          'kaldiramiyorsunuz.': 1,
#          'olarakbahar': 1,
#          'alacaklarabenden': 1,
#          'alabilir.Kargo': 1,
#          'BİRCEKETTİ...YENİ': 1,
#          'hoş.ketenimsi': 1,
#          'uzaktanyakınfan': 1,
#          'ayarlanabilirkaliteli': 1,
#          'kiçıplak': 1,
#          'haligörüyorsunuz': 1,
#          'oldugunuokudum': 1,
#          'biraktirirdi': 1,
#          'kaıltelı': 1,
#          'askıayarlanabilir': 1,
#          'göndermeyede': 1,
#          'Kollarıkatlanılarak': 1,
#          'satıştaymış': 1,
#          'göregayett': 1,
#          'SILE': 1,
#          'kadargetirip': 1,
#          'inanılmZ': 1,
#          'Allahımmmmmm!': 1,
#          '‘kendi': 1,
#          't-shirtyollamışlar': 1,
#          'belirteyim1.61': 1,
#          '174e60kiloyum': 1,
#          'sardı,küpe': 1,
#          'gölün': 1,
#          'duruşuda,': 1,
#          'cis': 1,
#          'bayahevesliyimdim': 1,
#          'kaldırsan': 1,
#          'oldu...Gülada': 1,
#          'ettim..Üst': 1,
#          'güzelrahatsızlık': 1,
#          'cikarabilirdi.': 1,
#          'markasındanalınabilecek': 1,
#          'sıkar,o': 1,
#          'kaldımm.': 1,
#          'istedim.Saygılar🙂': 1,
#          'tabi.Kalıbı': 1,
#          'capcanlı.baskıya,': 1,
#          'almıştım,rahatlık': 1,
#          'hepsininde.': 1,
#          'egik': 1,
#          'markayahic': 1,
#          'giymekistedigim': 1,
#          'parayaanca': 1,
#          'yazıkpazar': 1,
#          'kötükalın,alakasiz': 1,
#          'indirimdealmaya': 1,
#          'çorabıbiraz': 1,
#          'yarrr': 1,
#          'kişileridüşünmemeliyiz': 1,
#          'bayağıiyi.': 1,
#          'çikarirkenyirtilmasindan': 1,
#          'gonderebildiniz': 1,
#          'AYICIK': 1,
#          'sevdimbelden': 1,
#          'pedininayrı': 1,
#          'kendinisalmış....': 1,
#          'kararverebilirsiniz.': 1,
#          'getirmekbiraz': 1,
#          'Deterjanlı': 1,
#          'Jarsesi': 1,
#          'de.Minik': 1,
#          'kışmındataşlama': 1,
#          'Fiyattına': 1,
#          'zayıflıyosunuz;))': 1,
#          'bırürün.': 1,
#          'güzelbasen': 1,
#          'elbıse.Begenen': 1,
#          'aldımhepsine': 1,
#          'değilmorumsu,': 1,
#          'kumaşmükemmel...kurtarıcı': 1,
#          'bombalama': 1,
#          'var.magazalarda': 1,
#          'tefedutluydum': 1,
#          '👍👏👏ürün': 1,
#          'naylon...': 1,
#          'aldim..fakat': 1,
#          'xlgiyiyorum.': 1,
#          'sivideterjan': 1,
#          'ozude,bele': 1,
#          'atletkaliplari': 1,
#          'kg87xl': 1,
#          'iyikızım': 1,
#          'uptowna': 1,
#          'ferahlığıyla': 1,
#          'potlukyok,': 1,
#          'güZeller': 1,
#          'bambus': 1,
#          'güzelmiş.1.62': 1,
#          'kaliplqri': 1,
#          'Addax’ınoversize': 1,
#          'gercegi': 1,
#          'dikişlerigibi': 1,
#          'diye27': 1,
#          'değil.gomlek': 1,
#          'biforma': 1,
#          'sardı36beden': 1,
#          'geyinməmdə': 1,
#          'dikişlerionun': 1,
#          'sülfile': 1,
#          'sorryiade': 1,
#          'dönemindeeşofman': 1,
#          'kapatıpyanlardan': 1,
#          'Sütyenile': 1,
#          'genelde.36': 1,
#          'dolayıdökümlü': 1,
#          'yakışıklısı': 1,
#          'üslük': 1,
#          'dabilekleri': 1,
#          'Omuzlarinaben': 1,
#          'aynı…': 1,
#          'kucukalınmasını': 1,
#          'acıtiyor.': 1,
#          'pantolonyollandı.?': 1,
#          'tüylendi.tam': 1,
#          'YıldıZ': 1,
#          'duruyorsunuzboyum': 1,
#          'Edit:Aldigim': 1,
#          'departmanı': 1,
#          'kullanılabiliyor.Harika': 1,
#          'uymayanlarkullanmasın': 1,
#          'yükseltilmesi': 1,
#          'bayıldım.resimde': 1,
#          'yuksekl': 1,
#          'gezimde': 1,
#          'edecektim..verdiğim': 1,
#          'ürün👏teşekkürler': 1,
#          'canlikii': 1,
#          'alın,ince': 1,
#          'hafifvolanlı': 1,
#          'işkenceresmen': 1,
#          'Bedel.': 1,
#          'hoş.Gömlek': 1,
#          'Amblemler': 1,
#          'almasaydım🥰': 1,
#          'incelemeden😬': 1,
#          'tişörtgibi...': 1,
#          'tisortlerden,': 1,
#          'kargoyaverirdi': 1,
#          '👍🏻ürünün': 1,
#          'muhteşembayıldımmm': 1,
#          'ayrıcabasenlerim': 1,
#          'ürün☺️elbise': 1,
#          'hiçyanaşmasın': 1,
#          'biraz😞Biz': 1,
#          'tril,kalıp': 1,
#          'kemerledegiyebilirim.': 1,
#          'sarisigeldi.': 1,
#          'çorapgiydiğim': 1,
#          'kısmındaniğnelemek': 1,
#          'bedeninizialabilirsiniz.göğüs': 1,
#          'bedavadanreklamını': 1,
#          'denemişti.': 1,
#          'güzelemeği': 1,
#          'altı.bide': 1,
#          'elbise.Belki': 1,
#          'etmedi.1.65': 1,
#          'Koldetayları': 1,
#          'Kolaykırışmaması': 1,
#          'kısmıylaalakası': 1,
#          'soyulmadi': 1,
#          'aldım;bel': 1,
#          'deyişle': 1,
#          'boylulardamankendeki': 1,
#          'corapida': 1,
#          'aldımust': 1,
#          'bolluguda': 1,
#          'hatasınınmümkün': 1,
#          'göstermez.Bel': 1,
#          'toparlarken,': 1,
#          'biyelerden': 1,
#          'alımyaptık.': 1,
#          'epeyfarklı': 1,
#          'ulaşıncafarkettim': 1,
#          ...})

# %%
top_200 = review_counts.most_common()[0:200]

# %%
top_keywords = [i for i,j in top_200]
top_keywords
# Out:
# ['çok',
#  'güzel',
#  'bir',
#  'beden',
#  'ama',
#  've',
#  'tam',
#  'aldım',
#  'gibi',
#  'ürün',
#  'Çok',
#  'oldu',
#  'kumaşı',
#  'için',
#  '',
#  'kaliteli',
#  'geldi',
#  'büyük',
#  'cok',
#  'de',
#  'biraz',
#  'iade',
#  'iyi',
#  'daha',
#  'da',
#  'Ürün',
#  'rahat',
#  'alın',
#  'değil',
#  'rengi',
#  'bu',
#  'beğendim',
#  'gayet',
#  'boy',
#  'bi',
#  'küçük',
#  'bol',
#  'harika',
#  'tavsiye',
#  'bedeninizi',
#  'dar',
#  'kalitesi',
#  'var',
#  'göre',
#  'guzel',
#  'ederim',
#  'ben',
#  'fakat',
#  'kilo',
#  'uzun',
#  'şık',
#  'kiloyum',
#  'olarak',
#  'ince',
#  'o',
#  'kadar',
#  'oldu.',
#  'Kumaşı',
#  'kalıbı',
#  'duruyor',
#  'kumaş',
#  'kısa',
#  'elbise',
#  'göründüğü',
#  'duruşu',
#  '36',
#  'boyu',
#  '1',
#  'kısmı',
#  's',
#  'kendi',
#  'iç',
#  'aşırı',
#  '38',
#  'güzel.',
#  'Tam',
#  'alabilirsiniz',
#  'kesinlikle',
#  'ettim',
#  'uygun',
#  'm',
#  'yok',
#  '.',
#  'bedeni',
#  'diye',
#  'ki',
#  'hem',
#  'Güzel',
#  'kalıp',
#  'hiç',
#  'Rengi',
#  'bile',
#  'teşekkürler',
#  'kötü',
#  'almıştım',
#  'M',
#  'rağmen',
#  'L',
#  'hoş',
#  'sipariş',
#  'bayıldım',
#  'sadece',
#  'ile',
#  'gerçekten',
#  'renk',
#  '34',
#  'kalın',
#  'aynı',
#  'aldim',
#  'ancak',
#  'kg',
#  'bana',
#  'giyiyorum',
#  'fiyata',
#  'geldi.',
#  'olduğu',
#  'bence',
#  'aldım.',
#  'ne',
#  'tatlı',
#  '2',
#  'teşekkür',
#  'boyum',
#  'hızlı',
#  'S',
#  'kargo',
#  'geniş',
#  'baya',
#  'her',
#  'urun',
#  'bel',
#  'Harika',
#  'yazlık',
#  'salaş',
#  'mükemmel',
#  'gösteriyor',
#  'tercih',
#  'Ürünün',
#  ',',
#  'istediğim',
#  '40',
#  'dokusu',
#  'durdu',
#  'Bu',
#  'fazla',
#  'en',
#  'ürünü',
#  'fiyatına',
#  'pantolon',
#  'yüzden',
#  'tık',
#  'hafif',
#  'tek',
#  'açık',
#  'Gayet',
#  'yumuşacık',
#  'onun',
#  'ürün.',
#  'hediye',
#  'dışında',
#  'Bir',
#  'değil.',
#  'Ben',
#  'ürünün',
#  'ederim.',
#  'ediyorum',
#  'normalde',
#  'icin',
#  'memnun',
#  'üst',
#  'beli',
#  'alınabilir',
#  'tiril',
#  'rengini',
#  'modeli',
#  'zaten',
#  'sonra',
#  'beğenmedim',
#  'xs',
#  'sorun',
#  'farklı',
#  'kalite',
#  'Cok',
#  'falan',
#  'begendim',
#  'var.',
#  'güzel,',
#  'severek',
#  'fiyat',
#  'belli',
#  'beğendim.',
#  'iki',
#  'oversize',
#  'olur',
#  'yine',
#  'Kalıbı',
#  'kalitesiz',
#  'olsun',
#  'alınmalı',
#  'kilom']

# %%
turkish_chars = {
'ğ':'g',
'ü':'u',
'ı':'i',
'ş':'s',
'ç':'c',
'ö':'o'}

# %%
def replace_turkish_chars(text):
    for k,v in turkish_chars.items():
        text = text.replace(k, v)
    return text

# %%
data_reviews['comment'] = data_reviews['comment'].str.lower()
data_reviews['comment_non_turk_chars'] = data_reviews['comment'].apply(replace_turkish_chars)

# %%
data_reviews['comment_non_turk_chars']
# Out:
# 0          75c goguse s beden aldim spor icin daha da sar...
# 1                             fiyati yuksek ama cok memnunum
# 2          yorumlara ve beden tablosuna bakarak 1 beden b...
# 3                         cok kisa iade ettim. siradan geldi
# 4                                    renkler daha canli. hos
#                                  ...
# 6176836                                 cok guzel begendim 👍
# 6176837    pamuk degil sentetik.. ve bekledigimiz urun de...
# 6176838    kisa hazirlik bu fiyata cok iyi aldik. fakat s...
# 6176839    urun fotografta gozuktugu gibi fakat kalibi as...
# 6176840    ne gorunuyorsa o gelmis, tesekkurler, ayrica h...
# Name: comment, Length: 6176841, dtype: object

# %%
negative = [
'iade',
'geri',
'iptal',
'gönderdim',
'kargoladım',
'memnun kalm',
'beden',
'uymadı',
'olmadı',
'beğenm',
'dar',
'bol',
'geniş',
'defolu',
'hatalı',
'bozuk',
'kırık',
'büyük',
'küçük',
'sıkı',
'çalışmıyor',
'çalışmadı',
'değil',
'bi',
'aşırı',
'farklı',
'kalitesiz',
]

positive = [
'tam',
'oldu',
'harika',
'bayıld',
'süper',
'mükemmel',
'beğend',
'müthiş',
'tavsiye ederim',
'sağol',
'sağ ol',
'sorunsuz',
'teşekkür',
'memnun kal',
'memnun old',
'gayet',
'güzel',
'kaliteli',
'alın',
'rahat',    
'bedeninizi' ,  
'ederim',
'şık',
'alabilirsiniz',
'hoş',
'yumuşacık',
'alınabilir',
'severek',
]

# %%
negative = [replace_turkish_chars(n) for n in negative]
positive = [replace_turkish_chars(p) for p in positive]

# %%
negative[0:5]
# Out:
# ['iade', 'geri', 'iptal', 'gonderdim', 'kargoladim']

# %%
def look_for_positives(text):
    pos = 0
    for p in positive:
        if p in text:
            pos += 1 
    return pos

# %%
def look_for_negatives(text):
    neg = 0
    for n in negative:
        if n in text:
            neg += 1   
    return neg

# %%
data_reviews['pos_comment'] = data_reviews['comment_non_turk_chars'].apply(look_for_positives)
data_reviews['neg_comment'] = data_reviews['comment_non_turk_chars'].apply(look_for_negatives)

# %%
(data_reviews['pos_comment']/data_reviews['rate']).mean()
# Out:
# 0.4083205638583467

# %%
nltk.download('stopwords')
stop_word_list = nltk.corpus.stopwords.words('turkish')  
stop_word_list = [replace_turkish_chars(i) for i in stop_word_list]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\IsmailKaraman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(tokens):
    filtered_tokens = [token for token in tokens if token not in stop_word_list]#stop word'lerden temizlenir.  
    return filtered_tokens

# %%
def remove_word_contains_numeric(text):
    return re.sub(r'\w*\d\w*', ' ', text)

# %%
def remove_nonword_chars(text):
    return re.sub(r'[\W_]+', ' ', text)

# %%
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

# %%
def remove_emojis(text):
    return emoji_pattern.sub(r'', text)

# %%
def lemmatize_verbs(words):
    lemmatizer = zeyrek.MorphAnalyzer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word)[0][0]
        lemmas.append(lemma)
    return lemmas

# %%
def preprocess(text):
    
    text = text.lower()
    text = text.strip()
    text = remove_stopwords(text)
    text = remove_word_contains_numeric(text)
    text = remove_emojis(text)
    text = remove_nonword_chars(text)
    text = text.split(' ')
    text = lemmatize_verbs(text)
    text = [word for word in text if len(word) < 25 and len(word) >= 2]
    text = ' '.join(text)
    
    return text

# %%
data_reviews['preprocessed_text'] = data_reviews['comment'].apply(preprocess)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-a8cc5f7d5336> in <module>
# ----> 1 data_reviews['preprocessed_text'] = data_reviews['comment'].apply(preprocess)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-115-e93a0e6d1c0b> in preprocess(text)
#       1 def preprocess(text):
#       2
# ----> 3     text = remove_stopwords(text)
#       4     text = remove_word_contains_numeric(text)
#       5     text = remove_emojis(text)
#
# NameError: name 'remove_stopwords' is not defined

# %%
stop
# Out:
# WARNING:root:APPENDING RESULT: <(kütüphane_Noun)(-)(kütüphane:noun_S + a3sg_S + pnon_S + nom_ST + li:with_S + adjectiveRoot_ST)>
# 'kütüphaneli'

# %%
X = []
for sentence in x:

    review = re.sub('\W+', ' ', sentence)
    review = re.sub("\d+", "", review)
    review = review.strip()
    review = review.replace('I','ı') #lower() yapıldığı zaman I harfi i olarak çevirildiğinden dolayı replace ile düzeltildi.
    review = review.replace('İ','i') 
    review = review.lower()
    review = review.split()
    tokens = remove_stopword(review)
    corrected_text = " ".join(tokens)
    X.append(corrected_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,4))

# %%
text_list=[]

for text in df_copy.text:
    text = text.lower()  #Büyük harften -Küçük harfe çevirme
    text = re.sub("[^abcçdefgğhıijklmnoöprsştuüvyz]"," ",text)
    text=nltk.word_tokenize(text) # splits the words that are in the sentence from each other.
    text =[word for word in text if not word in set(stopwords.words("turkish"))]
    lemma=nlp.WordNetLemmatizer()
    text=[lemma.lemmatize(word) for word in text] # this code finds the root of the word for a word in the sentence and change them to their root form.
    text=" ".join(text)
    text_list.append(text) # store sentences in list

# %%
data_qa.head()
# Out:
#    product_content_id platform  supplier_id  \
# 0           100268920      IOS       215473
# 1            91760306      IOS       132710
# 2           102152800      IOS       299298
# 3           102286287      IOS       202978
# 4            66184893      IOS       204213
#
#                                             question  \
# 0  İstek üzerine bir kutu içinde 2.3. Ve 5. Sırad...
# 1                Beden tablosu paylaşabilir misiniz?
# 2  1.90 Boy, 88 kiloyum. Oversize için ideal boy ...
# 3                 boy 173 kilo 62 hangi beden olmalı
# 4                         85 kiloyum L beden olur mu
#
#                                               answer
# 0  Merhaba, maalesef şu an için talebinizi karşıl...
# 1  Merhaba, beden tablosu aşağıdaki gibidir. Kend...
# 2        Merhaba efendim L beden sizin için uygundur
# 3  Merhabalar, S beden sizin için uygundur sorun ...
# 4                   Merhaba efendim  Rahatlıkla olur

# %%
len(data_reviews['product_content_id'].unique())
# Out:
# 462323

# %%
data_reviews.groupby(by=['product_content_id']).agg({'rate':'mean', 'review_like_count':'sum'})
# Out:
#                         rate  review_like_count
# product_content_id
# 48921               3.333333                0.0
# 63682               4.500000                0.0
# 63785               4.333333                0.0
# 82578               4.000000                0.0
# 93160               2.000000                0.0
# ...                      ...                ...
# 130602703           5.000000                0.0
# 130608983           3.571429                1.0
# 130609537           4.000000                0.0
# 130619364           4.428571                0.0
# 130620963           4.666667                2.0
#
# [462323 rows x 2 columns]

# %%
data_reviews[data_reviews['product_content_id']==130608983]
# Out:
#          product_content_id  rate  \
# 845890            130608983     5
# 971655            130608983     5
# 2046423           130608983     5
# 4018601           130608983     1
# 4380555           130608983     3
# 4958795           130608983     1
# 6133277           130608983     5
#
#                                                    comment  review_like_count  \
# 845890   çok rahat tam yazlık pantalon iyiki almışım he...                NaN
# 971655   Kumaşı çok güzel. Normal bedenimden bir beden ...                1.0
# 2046423                            Tarzını beğendim 👍🏻👍🏻👍🏻                NaN
# 4018601                                       Berbat ötesi                NaN
# 4380555  Malesef ürünüm yanlış renkle geldi o yüzden ia...                NaN
# 4958795  Ben mavi sipariş  verdim   bana  yeşil  gönder...                NaN
# 6133277                          Tüm renklerini alabilirşm                NaN
#
#          supplier_id
# 845890        176704
# 971655        176704
# 2046423       176704
# 4018601       176704
# 4380555       176704
# 4958795       176704
# 6133277       176704
